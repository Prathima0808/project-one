# %%
import os
import pandas as pd

# %%
data_df=pd.read_csv('survey.csv')
data_df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data_df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
clean_data_df=data_df[['Age','Gender','Country','tech_company','benefits','wellness_program','mental_health_consequence','mental_health_interview']]
clean_data_df.head()
clean_data_df['Age'].unique()
print(len(clean_data_df['Gender'].unique()))
clean_data_df['Gender'].unique()
# Out:
# 49
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# ### Female:
# Female,'female','Trans-female','Cis Female', 'F','Woman','f','Femake','woman','Female ','cis-female/femme','Trans woman','Female (trans)','Female (cis)', 'femail'
#
# ### Male:
# 'M','Male', 'male', 'm', 'Male-ish', 'maile','something kinda male?','Cis Male','Mal', 'Male (CIS)','Make','Guy (-ish) ^_^','male leaning androgynous','Male ', 'Man', 'msle','Mail', 'cis male', 'Malr','Cis Man','ostensibly male, unsure what that really means'
#
# ### Other:
# 'queer/she/they','non-binary','Nah', 'All', 'Enby','fluid', 'Genderqueer', 'Androgyne', 'Agender','Neuter','A little about you','p'

# %%
clean_data_df['Country'].unique()
gbc=clean_data_df.groupby('Country').count()
print(gbc)
# Out:
#                         Age  Gender  tech_company  benefits  wellness_program  \
# Country
# Australia                21      21            21        21                21
# Austria                   3       3             3         3                 3
# Bahamas, The              1       1             1         1                 1
# Belgium                   6       6             6         6                 6
# Bosnia and Herzegovina    1       1             1         1                 1
# Brazil                    6       6             6         6                 6
# Bulgaria                  4       4             4         4                 4
# Canada                   72      72            72        72                72
# China                     1       1             1         1                 1
# Colombia                  2       2             2         2                 2
# Costa Rica                1       1             1         1                 1
# ...

# %%
#clean_data_df['tech_company'].describe()
clean_data_df['tech_company'].unique()
gbt=clean_data_df.groupby('tech_company').count()
print(gbt)
# Out:
#                Age  Gender  Country  benefits  wellness_program  \
# tech_company
# No             228     228      228       228               228
# Yes           1031    1031     1031      1031              1031
#
#               mental_health_consequence  mental_health_interview
# tech_company
# No                                  228                      228
# Yes                                1031                     1031
